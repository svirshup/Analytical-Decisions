# %% [markdown]
# # Homework Numero Uno
# ## Scott Virshup
# ## Analytical Decision Making
#
# ### Table of Contents
# 1. [Exercise One](#ex1)
#     1. [Part 1](#ex1a)
#     1. [Part 2](#ex1b)
#     1. [Part 3](#ex1c)
#     1. [Part 4](#ex1d)
# 1. [Exercise Two](#ex2)
#     1. [Part 1](#ex2a)
#     1. [Part 2](#ex2b)
#     1. [Part 3](#ex2c)
#     1. [Part 4](#ex2d)
#     1. [Part 5](#ex2e)
# 1. [Exercise Three](#ex3)
#     1. [Part 1](#ex3a)
#     1. [Part 2](#ex3b)
#     1. [Part 3](#ex3c)
#     1. [Part 4](#ex3d)
#     1. [Part 5](#ex3e)
#     1. [Part 6](#ex3f)

# %%
# !pip install cvxopt
# !pip install cvxpy
# Out:
# ...
# google-gax 0.15.16 has requirement requests<3.0dev,>=2.13.0, but you'll have requests 2.9.1 which is incompatible.
# google-cloud-storage 1.6.0 has requirement requests>=2.18.0, but you'll have requests 2.9.1 which is incompatible.
# google-cloud-spanner 0.29.0 has requirement requests<3.0dev,>=2.18.4, but you'll have requests 2.9.1 which is incompatible.
# google-cloud-pubsub 0.29.4 has requirement psutil<6.0dev,>=5.2.2, but you'll have psutil 4.3.0 which is incompatible.
# google-cloud-bigquery 0.28.0 has requirement requests>=2.18.0, but you'll have requests 2.9.1 which is incompatible.
# google-api-core 0.1.4 has requirement requests<3.0.0dev,>=2.18.0, but you'll have requests 2.9.1 which is incompatible.
# datalab 1.1.2 has requirement ipykernel==4.5.2, but you'll have ipykernel 4.8.2 which is incompatible.
# cufflinks 0.12.1 has requirement plotly>=2.0.0, but you'll have plotly 1.12.5 which is incompatible.
# ...

# %% [markdown]
# # Exercise One: Sensitivity Analysis<a id='ex1'></a>
#
# ## Part 1: Optimization Problem<a id='ex1a'></a>

# %% [markdown]
# ## What are the decision variables?
# Let $i={1,2,3,4}$ be in the index for the advertisers such that
# * $i=1$ is GEICO
# * $i=2$ is Delta
# * $i=3$ is T-Mobile
# * $i=4$ is Capital One
#
# Let $j={1,2}$ be the index for the category, such as $j=1$ is the Sports categorty and $j=2$ is the National category.
#
# So $x_{11}$ is the number of impressions for Geico in Sports and $x_{12}$ is the number of impressions for GEICO int he National category
#
#
# ## What is the objective?
#
# The objective of the platform, i.e., Washington Post, is to maximize advertising revenues. These revenues are driven by the cost per click charged to the advertisers, i.e., \$2.5 and the click-through rates.
#
# Let $\kappa_{ij}$ be the CTR of advertiser $i$ in category $j$. For instance, the CTR of T-Mobile in the sports category is $\kappa_{31}=1.0\%$, whereas its CTR in the National category is $\kappa_{32}=3.0\%$.
#
# The objective function is thus:
# \begin{equation}
# Objective=2.3\times \sum_{i=1}^4\sum_{j=1}^{2}  \kappa_{ij}\times x_{ij}
# \end{equation}
#
#
#
#
#
# ## What are the constraints?
# The first table provides the following constraints
#
# \begin{align}
# x_{11}&\geq 2,000,000\\
# x_{12}&\geq 1,000,000\\
# x_{22}&\geq 1,000,000\\
# x_{21}+x_{22}&\geq 2,000,000\\
# x_{31}&\geq 1,000,000\\
# x_{32}&\geq 1,000,000\\
# x_{31}+x_{32}&\geq 3,000,000\\
# x_{41}+x_{42}&\geq 2,000,000\\
# \end{align}
#
# "Assume that the Sports section gets six million views per day and the National section
# get five million views per day"
# This statement gives two constraints:
# \begin{align}
# \sum_{i=1}^{4}x_{i1}&\leq 6,000,000\\
# \sum_{i=1}^{4}x_{i2}&\leq 5,000,000\\
# \end{align}
#
# Non-negativity constraints are
# \begin{equation}
# x_{ij}\geq 0
# \end{equation}

# %% [markdown]
# ## Part 2: Optimal Solution<a id='ex1b'></a>

# %%
import numpy 
import math
import cvxpy as cvx
from numpy import *
from cvxpy import *
import pandas as pd


kappa=matrix([[2.5,2.0,1.0,1.5],[0.8,1.0,3.0,2.0]])
kappa1=kappa[0]
kappa2=kappa[1]
x1=cvx.Int(4,1)
x2=cvx.Int(4,1)

#Objective Function
Z1=sum_entries(kappa1*x1)*2.3/100
Z2=sum_entries(kappa2*x2)*2.3/100
objective = cvx.Maximize((Z1+Z2))

#Constraints that we identified before
c1=(sum_entries(x1))<=6*1000000#Capacity on Sports
c2=(sum_entries(x2))<=5*1000000#Capacity on Sports
c3=x1[0]>=2*1000000 # Geico must have at least 2m in sports
c4=x2[0]>=1*1000000 # Geico must have at least 1m in sports
c5=x2[1]>=1*1000000 # Delta must have at least 1m in sports
c6=x1[1]+x2[1]==2*1000000 # Delta's total # of impressions must be equal to 2m total
c7=x1[2]>=1*1000000# Tmobile must have at least 1m impression in sports
c8=x2[2]>=1*1000000# Tmobile must have at least 1m impression in national
c9=x1[2]+x2[2]==3*1000000 # Tmobile's total # of impressions must be equal 3m total
c10=x1[3]+x2[3]==2*1000000# Capital Obe's impression equal 2m
c=[c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,x1>=0,x2>=0]

prob = cvx.Problem(objective, c)
result = prob.solve()
print('The optimal revenue is ')
print(prob.value)
print('The optimal allocation in the sports category is')
print(x1.value)
print('The optimal allocation in the national category is')
print(x2.value)
# Out:
# The optimal revenue is
# 501399.9999979723
# The optimal allocation in the sports category is
# [[2999999.999997  ]
#  [ 999999.99997988]
#  [1000000.00003361]
#  [ 999999.99998853]]
# The optimal allocation in the national category is
# [[1000000.00000119]
#  [1000000.00002012]
#  [1999999.99996639]
#  [1000000.00001147]]

# %% [markdown]
# ##### Optimal Allocation
#
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million

# %% [markdown]
# ## Part 3: Sensitivity Analysis<a id='ex1c'></a>
#
# In each section, I replaced the initial kappa matrix with the new values, and then re-run the solver. To save space, I will simply output the table (like the one above) along with the optimal revenue that comes with this allocation.

# %%
import numpy 
import math
import cvxpy as cvx
from numpy import *
from cvxpy import *
import pandas as pd


kappa=matrix([[2.5,2,1.0,1.0],[0.8,1,3.0,2.0]])
kappa1=kappa[0]
kappa2=kappa[1]
x1=cvx.Int(4,1)
x2=cvx.Int(4,1)

#Objective Function
Z1=sum_entries(kappa1*x1)*2.3/100
Z2=sum_entries(kappa2*x2)*2.3/100
objective = cvx.Maximize((Z1+Z2))

#Constraints that we identified before
c1=(sum_entries(x1))<=6*1000000#Capacity on Sports
c2=(sum_entries(x2))<=5*1000000#Capacity on Sports
c3=x1[0]>=2*1000000 # Geico must have at least 2m in sports
c4=x2[0]>=1*1000000 # Geico must have at least 1m in sports
c5=x2[1]>=1*1000000 # Delta must have at least 1m in sports
c6=x1[1]+x2[1]==2*1000000 # Delta's total # of impressions must be equal to 2m total
c7=x1[2]>=1*1000000# Tmobile must have at least 1m impression in sports
c8=x2[2]>=1*1000000# Tmobile must have at least 1m impression in national
c9=x1[2]+x2[2]==3*1000000 # Tmobile's total # of impressions must be equal 3m total
c10=x1[3]+x2[3]==2*1000000# Capital Obe's impression equal 2m
c=[c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,x1>=0,x2>=0]

prob = cvx.Problem(objective, c)
result = prob.solve()
print('The optimal revenue is ')
print(prob.value)
print('The optimal allocation in the sports category is')
print(x1.value)
print('The optimal allocation in the national category is')
print(x2.value)
# Out:
# The optimal revenue is
# 489899.99999996927
# The optimal allocation in the sports category is
# [[2999999.99999974]
#  [ 999999.99999988]
#  [1000000.00000034]
#  [ 999999.99999995]]
# The optimal allocation in the national category is
# [[1000000.00000009]
#  [1000000.00000012]
#  [1999999.99999966]
#  [1000000.00000005]]

# %% [markdown]
# ##### Geico Sports 2%
# ###### Optimal Revenue: 466,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Geico Sports 3%
# ###### Optimal Revenue: 535,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Geico National 0.1%
# ###### Optimal Revenue: 485,300
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Geico National 1.1%
# ###### Optimal Revenue: 508,300
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Delta Sports 1.5%
# ###### Optimal Revenue: 489,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Delta Sports 2.5%
# ###### Optimal Revenue: 512,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Delta National 0.5%
# ###### Optimal Revenue: 489,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Delta National 1.5%
# ###### Optimal Revenue: 512,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### T-Mobile Sports 0.5%
# ###### Optimal Revenue: 489,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### T-Mobile Sports 1.5%
# ###### Optimal Revenue: 512,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### T-Mobile National 2.5%
# ###### Optimal Revenue: 478,400
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### T-Mobile National 3.5%
# ###### Optimal Revenue: 524,400
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Capital One Sports 1.5%
# ###### Optimal Revenue: 489,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Capital One Sports 2%
# ###### Optimal Revenue: 512,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Capital One National 1.5%
# ###### Optimal Revenue: 489,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million
#
# ##### Capital One National 2.5%
# ###### Optimal Revenue: 512,900
# | Company | Sports | National | Total
# | :---:|:---: | :---:|:---:
# | GEICO|3 million | 1 million|4 million
# | Delta|1 million | 1 million|2 million
# | T-Mobile|1 million | 2 million|3 million
# | Capital One|1 million | 1 million|2 million

# %% [markdown]
# ## Part 4: Results Analysis<a id='ex1d'></a>
#
# Since we were changing the click-through rates of certain brands, we were changing the amount of revenue that was obtained. When the click through rate was increased, the optimal revenue was also increased because clicks are what you get paid for. Within each range, the higher of the two ranges resulted in a larger optimal revenue. The interesting thing was that none of the impression allocations changed once they were calculated the first time.

# %% [markdown]
# # Exercise Two: Operations Excellence<a id='ex2'></a>
#
# ## Part 1: Optimization Problem<a id='ex2a'></a>

# %% [markdown]
# ##### What are the decision variables?
# We have two plants, A and B
# Each plant uses raw materials to create their "standard" or their "deluxe" products.
# For each product, they need to grind and polish them.
# standard products sell for 10 dollars, and deluxe products sell for 15 dollars.
#
# ##### What is the objective? (same for both plants)
# Maximize profit = 10(standard products) + 15(deluxe products)
#
#
# ##### What are the constraints?
# One 'constraint' is that we're using integer programming here. The reason being that it does not make logical sense to be able to create a fraction of a product. If the "standard" product were a table, it does not make sense to only be able to create 50% of a table. For this reason, we've limited the model to only be able to choose integer values for the optimal units of standard and deluxe.
#
# ##### Plant A
# * Raw material constraint: 4(standard) + 4(deluxe) <= 75
# * Grinding A: 4(standard) + 2(deluxe) <= 80
# * Polishing A: 2(standard) + 5(deluxe) <= 60
#
# ##### Plant B
# * Raw material constraint: 4(standard) + 4(deluxe) <= 45
# * Grinding B: 5(standard) + 3(deluxe) <= 60
# * Polishing B: 5(standard) + 6(deluxe) <= 75

# %% [markdown]
# ## Part 2: Optimal Solutions<a id='ex2b'></a>

# %%
import cvxopt
import numpy as np
from cvxopt import glpk


c=cvxopt.matrix([-10.0,-15.0], tc='d')
A=cvxopt.matrix([ [4.0,2.0,4.0,-1.0,0.0],[2.0,5.0,4.0,0.0,-1.0]],tc='d')
b = cvxopt.matrix([80.0,60.0,75.0,0.0,0.0],tc='d')
(status,x)=cvxopt.glpk.ilp(c,A,b,I=set([0,1]))
print("The Optimal for Plant A")
print(status)
print(x[0],x[1])
print(-sum(c.T*x))


c=cvxopt.matrix([-10.0,-15.0], tc='d')
A=cvxopt.matrix([ [5.0,5.0,4.0,-1.0,0.0],[3.0,6.0,4.0,0.0,-1.0]],tc='d')
b = cvxopt.matrix([60.0,75.0,45.0,0.0,0.0],tc='d')
(status,x)=cvxopt.glpk.ilp(c,A,b,I=set([0,1]))
print("The Optimal for Plant B")
print(status)
print(x[0],x[1])
print(-sum(c.T*x))
# Out:
# The Optimal for Plant A
# optimal
# 10.0 8.0
# 220.0
# The Optimal for Plant B
# optimal
# 0.0 11.0
# 165.0

# %% [markdown]
# ## Part 3: Joint Solution<a id='ex2c'></a>

# %%
c=cvxopt.matrix([-10.0,-15.0,-10.0,-15.0], tc='d')
A=cvxopt.matrix([ [4.0,4.0,2.0,-1.0,0.0],[2.0,5.0,3.0,6.0,4.0,4.0,0.0,-1.0]],tc='d')
b = cvxopt.matrix([80.0,60.0,60.0,120.0,0.0,0.0],tc='d')
(status,x)=cvxopt.glpk.ilp(c,A,b,I=set([0,1]))
print("The Optimal Joint solution")
print(status)
print(x[0],x[1])
print(-sum(c.T*x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-97bed606ec7d> in <module>()
#       1 c=cvxopt.matrix([-10.0,-15.0,-10.0,-15.0], tc='d')
# ----> 2 A=cvxopt.matrix([ [4.0,4.0,2.0,-1.0,0.0],[2.0,5.0,3.0,6.0,4.0,4.0,0.0,-1.0]],tc='d')
#       3 b = cvxopt.matrix([80.0,60.0,60.0,120.0,0.0,0.0],tc='d')
#       4 (status,x)=cvxopt.glpk.ilp(c,A,b,I=set([0,1]))
#       5 print("The Optimal Joint solution")
#
# TypeError: incompatible dimensions of subblocks

# %% [markdown]
# ## Part 4: Comments on Results<a id='ex2d'></a>

# %% [markdown]
# Honestly I was not able to get the joint solution working correctly. I tried many different ways of doing it, but there must have been something wrong in my notes and I wasn't able to get it working. However, I intuitively understand what should be happening here. The major difference is that instead of giving plant A 75kg of raw and plant B 45kg, it is allowing the model to make that allocation decision instead. This will intuitively improve the overall profit for the company. The only case it wouldn't improve it would be if 75-45 were already the optimal split, in which case it would stay the same. In general, adding additional constraints like the inital 75-45 split will only limit the maximium/minimum of the model.

# %% [markdown]
# ## Part 5: Recommendations<a id='ex2e'></a>

# %% [markdown]
# Before making recommendations to the CEO, I would first want to make sure I completely understood the business that I was evaluating. For instance, if it were impossible to logistically get more raw material to plant B, then it would not make sense to allow the model to allocate > 45 kg to plant B. For reasons like this, my recommendation to the CEO would be that plant B has more capacity and that their marginal profit is currently larger. I would then recommend that the CEO keep me around so I can help look into any possible ways to move raw material from A to B in the most cost-effective way.

# %% [markdown]
# # Exercise 3: Hotel La Quinta Motor Inns<a id='ex3'></a>
#
# ## Part 1<a id='ex3a'></a>
# According to the regression equation given above, which variable positively affect Profitability? Which variable negatively affect Profitability? Does this intuitively make sense? Why?
#
# ##### Which variables positively affect profitibility?
# * Price of the inn
#     * For a unit increase in price, profitibility will increase by 5.86 units, holding all else equal.
#     * This is not intuitive. This implies that continuously increasing the price of a unit in the inn, the profitibility will continue to increase. However, if you increase the price past a certain point, the profitibility will become zero because nobody will be willing to pay that much for an inn. This might be due to a limited range of prices for which this model was created with. The intuitive thing for this independent variable would be to have another transformed price variable with a negative coefficient, that would gradually turn the overall price effect negative.
# * College students in area
#     * For a unit increase in the number of college students in area, profitibility will increase by 1.75 units, holding all else equal.
#     * This makes sense intuitively. The size also makes sense, as more college students in the area would likely only slightly increase profitiblity during certain times of year (graduation, move-in day, etc.). The expectation here is that this variable would be strongly correlated with a seasonality dummy for those times of year.
#
# ##### Which variables negatively affect profitibility?
# * State population per inn
#     * For a unit increase in state population, profitibility will decrease by 5.41 units, holding all else equal.
#     * This does not make intuitive sense. States with large populations would presumably have more people traveling to/within it, which would increase demand for this inn, but instead this variable is strongly negative.
# * Square root of the median income in the area
#     * For a unit increase in square root of median income, profitibility will decrease by 3.09 units, holding all else equal.
#     * This variable makes sense under the assumption that this is a relatively low-value hotel chain. If the LQM Inns chain is low-value, then people in/visiting more wealthy areas would likely rather choose a nicer place to stay. This might also be correlated with the variable for the price of the inn, which would likely increase in areas that are wealthy to begin with.

# %% [markdown]
# ## Part 2<a id='ex3b'></a>
# Using this regression equation, LQM created a spreadsheet model to predict profitability. LQM collected data for several locations in California, which is provided in the excel spreadsheet on Canvas “LQM”. Using this spreadsheet, compute the profitability for each hotel. Which one has the highest profitability? Which one has the lowest profitability?
#
# ##### Highest profitibility
# Hotel 2 in Fresno, CA - Profitibility of 53.38
#
#
# ##### Lowest profitibility
# Hotel 8 in Los Angeles, CA - Profitibility of 23.45
#
# ##### Overall order
# * 2,	Fresno, California
# * 6,	Long Beach, California
# * 1,	Eureka, California
# * 3,	Fresno, California
# * 4,	Fresno, California
# * 14,	South Lake Tahoe, California
# * 12,	South Lake Tahoe, California
# * 13,	South Lake Tahoe, California
# * 10,	South Lake Tahoe, California
# * 15,	South Lake Tahoe, California
# * 11,	South Lake Tahoe, California
# * 16,	South Lake Tahoe, California
# * 5,	Fresno, California
# * 9,	Los Angeles, California
# * 7,	Los Angeles, California
# * 8,	Los Angeles, California

# %% [markdown]
# ## Part 3<a id='ex3a'></a>
#
# LQM has a budget of $10 million to spend on hotels. Suppose we used a “greedy” approach where we selected the most profitable hotels until we ran out of budget. So we would start by the most profitable, and then if we had enough budget left, we would buy the hotel we predict to be the second most profitable, and so on.
#
# ##### Describe what we would do with this approach, i.e., which hotels would we purchase?
# * What would our total predicted profitability be? (This is the sum of the predicted
# profitability of all hotels we purchase.)
# * If we are trying to maximize our total predicted profitability, is this a good approach? How
# about if we were trying to maximize the average predicted profitability of the hotels we
# select? How about if we had a budget of 20 million instead of 10 million?

# %% [markdown]
# ##### Describe what we would do with this approach, i.e., which hotels would we purchase?
# With out budget of $10 million, we would purchase just one hotel, and that would be hotel number 2 in Fresno, CA. It costs $10 million alone, so that maxes out our budget.
#
# ##### What would our total predicted profitibility be?
# Since we're purchasing just one hotel, the profitibility will be 53.38
#
# ##### If we are trying to maximize our total predicted profitibility, is this a good approach? How about if we were trying to maximize the average predicted profitibility of the hotels we selected? How about if we had a budget of 20 million instead of 10 million?
# This is not the best approach to maximize total profitibility. As we'll see in the next question, this single hotel is not the best when you have only 10 million to spend, since some hotels are much cheaper than this one, and their combined profitability will be higher. On the other hand, if we were trying to optimize the average profitibility of all the hotels we owned, then this would be the optimial solution. There is no way to get a higher average than owning 1 hotel with the strongest individual profitibility. Any additional hotel purchased would lower the average. Increasing budget from 10 to 20 million would change the hotels purchased, but would not change the logic here. The method outlined in this question would be best for obtaining the highest average, but not the total highest profitibility.

# %% [markdown]
# ## Part 4<a id='ex3a'></a>
# Now, build an optimization model to select hotels given the 10 million budget.
#
# ##### Write out the optimization problem. Make sure to detail the decision variables, the objective function and the constraints.
# Decision Variables:
# * Hotels (numbered 1 - 16)
#     * H1
#     * H2
#     * . . .
#     * H16
# * Variables
#     * P - Price
#     * Y - Profitibility
#
# Objective Function:
# * The objective is to maximize the profitibility of the hotels
#
# Constraints:
# * total price of all hotels to be built must be >= 10,000,000
#
# ##### What is the optimal solution? Give the values of the decision variables and the optimal objective function value.
#
#
# ##### Does the optimal solution make sense intuitively? How does it compared to the greedy solution?

# %%
import math
import numpy as np
import cvxpy as cvx

# Definition of the Variables
y1 = cvx.Bool()
y2 = cvx.Bool()
y3 = cvx.Bool()
y4 = cvx.Bool()
y5 = cvx.Bool()
y6 = cvx.Bool()
y7 = cvx.Bool()
y8 = cvx.Bool()
y9 = cvx.Bool()
y10 = cvx.Bool()
y11 = cvx.Bool()
y12 = cvx.Bool()
y13 = cvx.Bool()
y14 = cvx.Bool()
y15 = cvx.Bool()
y16 = cvx.Bool()

# price
p1 = 2925000
p2 = 10000000
p3 = 3750000
p4 = 3500000
p5 = 325000
p6 = 8950000
p7 = 1950000
p8 = 1750000
p9 = 4900000
p10 = 1650000
p11 = 1125000
p12 = 2500000
p13 = 1975000
p14 = 3750000
p15 = 1475000
p16 = 750000

# profitibility
f1 = 44.24
f2 = 53.38
f3 = 43.02
f4 = 42.61
f5 = 37.34
f6 = 49.1
f7 = 23.78
f8 = 23.45
f9 = 28.67
f10 = 38.88
f11 = 38.01
f12 = 40.29
f13 = 39.42
f14 = 42.36
f15 = 38.59
f16 = 37.39

#Objective Function
objective_profit = ((f1*y1)+(f2*y2)+(f3*y3)+(f4*y4)+(f5*y5)+(f6*y6)+(f7*y7)+(f8*y8)+(f9*y9)+(f10*y10)+
                   (f11*y11)+(f12*y12)+(f13*y13)+(f14*y14)+(f15*y15)+(f16*y16))
objective = cvx.Maximize(objective_profit)

#Constraints
# total budget constraint
c1=((p1*y1)+(p2*y2)+(p3*y3)+(p4*y4)+(p5*y5)+(p6*y6)+(p7*y7)+(p8*y8)+(p9*y9)+(p10*y10)+(p11*y11)+
    (p12*y12)+(p13*y13)+(p14*y14)+(p15*y15)+(p16*y16)) <= 10000000
con = [c1]

#Solution
prob = cvx.Problem(objective, con)
prob.solve()

# Print the Results
print('Hotel 1 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y1.value,0))+
     ' ------ Price: $'+format(p1))
print('Hotel 2 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y2.value,0))+
     ' ----- Price: $'+format(p2))
print('Hotel 3 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y3.value,0))+
     ' ------ Price: $'+format(p3))
print('Hotel 4 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y4.value,0))+
     ' ------ Price: $'+format(p4))
print('Hotel 5 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y5.value,0))+
     ' ------ Price: $'+format(p5))
print('Hotel 6 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y6.value,0))+
     ' ----- Price: $'+format(p6))
print('Hotel 7 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y7.value,0))+
     ' ------ Price: $'+format(p7))
print('Hotel 8 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y8.value,0))+
     ' ------ Price: $'+format(p8))
print('Hotel 9 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y9.value,0))+
     ' ------ Price: $'+format(p9))
print('Hotel 10 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y10.value,0))+
     ' ------ Price: $'+format(p10))
print('Hotel 11 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y11.value,0))+
     ' ------ Price: $'+format(p11))
print('Hotel 12 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y12.value,0))+
     ' ------ Price: $'+format(p12))
print('Hotel 13 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y13.value,0))+
     ' ------ Price: $'+format(p13))
print('Hotel 14 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y14.value,0))+
     ' ------ Price: $'+format(p14))
print('Hotel 15 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y15.value,0))+
     ' ------ Price: $'+format(p15))
print('Hotel 16 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y16.value,0))+
     ' ------ Price: $'+format(p16))
print('Total Profitibility:')
print(format(round(
(f1 if round(y1.value,0) >= 1.0 else 0) + 
(f2 if round(y2.value,0) >= 1.0 else 0) + 
(f3 if round(y3.value,0) >= 1.0 else 0) + 
(f4 if round(y4.value,0) >= 1.0 else 0) + 
(f5 if round(y5.value,0) >= 1.0 else 0) + 
(f6 if round(y6.value,0) >= 1.0 else 0) + 
(f7 if round(y7.value,0) >= 1.0 else 0) + 
(f8 if round(y8.value,0) >= 1.0 else 0) + 
(f9 if round(y9.value,0) >= 1.0 else 0) + 
(f10 if round(y10.value,0) >= 1.0 else 0) + 
(f11 if round(y11.value,0) >= 1.0 else 0) + 
(f12 if round(y12.value,0) >= 1.0 else 0) + 
(f13 if round(y13.value,0) >= 1.0 else 0) + 
(f14 if round(y14.value,0) >= 1.0 else 0) + 
(f15 if round(y15.value,0) >= 1.0 else 0) + 
(f16 if round(y16.value,0) >= 1.0 else 0)
,2)))
# Out:
# Hotel 1 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $2925000
# Hotel 2 ------- If 0, do not purchase if 1, purchase ------ -0.0 ----- Price: $10000000
# Hotel 3 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $3750000
# Hotel 4 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $3500000
# Hotel 5 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $325000
# Hotel 6 ------- If 0, do not purchase if 1, purchase ------ -0.0 ----- Price: $8950000
# Hotel 7 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $1950000
# Hotel 8 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $1750000
# Hotel 9 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $4900000
# Hotel 10 ------ If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1650000
# Hotel 11 ------ If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1125000
# ...

# %%
# Increasing the budget to 20 million

import math
import numpy as np
import cvxpy as cvx

# Definition of the Variables
y1 = cvx.Bool()
y2 = cvx.Bool()
y3 = cvx.Bool()
y4 = cvx.Bool()
y5 = cvx.Bool()
y6 = cvx.Bool()
y7 = cvx.Bool()
y8 = cvx.Bool()
y9 = cvx.Bool()
y10 = cvx.Bool()
y11 = cvx.Bool()
y12 = cvx.Bool()
y13 = cvx.Bool()
y14 = cvx.Bool()
y15 = cvx.Bool()
y16 = cvx.Bool()

# price
p1 = 2925000
p2 = 10000000
p3 = 3750000
p4 = 3500000
p5 = 325000
p6 = 8950000
p7 = 1950000
p8 = 1750000
p9 = 4900000
p10 = 1650000
p11 = 1125000
p12 = 2500000
p13 = 1975000
p14 = 3750000
p15 = 1475000
p16 = 750000

# profitibility
f1 = 44.24
f2 = 53.38
f3 = 43.02
f4 = 42.61
f5 = 37.34
f6 = 49.1
f7 = 23.78
f8 = 23.45
f9 = 28.67
f10 = 38.88
f11 = 38.01
f12 = 40.29
f13 = 39.42
f14 = 42.36
f15 = 38.59
f16 = 37.39

#Objective Function
objective_profit = ((f1*y1)+(f2*y2)+(f3*y3)+(f4*y4)+(f5*y5)+(f6*y6)+(f7*y7)+(f8*y8)+(f9*y9)+(f10*y10)+
                   (f11*y11)+(f12*y12)+(f13*y13)+(f14*y14)+(f15*y15)+(f16*y16))
objective = cvx.Maximize(objective_profit)

#Constraints
# total budget constraint
c1=((p1*y1)+(p2*y2)+(p3*y3)+(p4*y4)+(p5*y5)+(p6*y6)+(p7*y7)+(p8*y8)+(p9*y9)+(p10*y10)+(p11*y11)+
    (p12*y12)+(p13*y13)+(p14*y14)+(p15*y15)+(p16*y16)) <= 20000000
con = [c1]

#Solution
prob = cvx.Problem(objective, con)
prob.solve()

# Print the Results
print('Hotel 1 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y1.value,0))+
     ' ------ Price: $'+format(p1))
print('Hotel 2 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y2.value,0))+
     ' ----- Price: $'+format(p2))
print('Hotel 3 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y3.value,0))+
     ' ----- Price: $'+format(p3))
print('Hotel 4 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y4.value,0))+
     ' ------ Price: $'+format(p4))
print('Hotel 5 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y5.value,0))+
     ' ------ Price: $'+format(p5))
print('Hotel 6 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y6.value,0))+
     ' ------ Price: $'+format(p6))
print('Hotel 7 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y7.value,0))+
     ' ------ Price: $'+format(p7))
print('Hotel 8 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y8.value,0))+
     ' ------ Price: $'+format(p8))
print('Hotel 9 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y9.value,0))+
     ' ------ Price: $'+format(p9))
print('Hotel 10 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y10.value,0))+
     ' ------ Price: $'+format(p10))
print('Hotel 11 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y11.value,0))+
     ' ------ Price: $'+format(p11))
print('Hotel 12 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y12.value,0))+
     ' ------ Price: $'+format(p12))
print('Hotel 13 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y13.value,0))+
     ' ------ Price: $'+format(p13))
print('Hotel 14 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y14.value,0))+
     ' ----- Price: $'+format(p14))
print('Hotel 15 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y15.value,0))+
     ' ------ Price: $'+format(p15))
print('Hotel 16 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y16.value,0))+
     ' ------ Price: $'+format(p16))
print('Total Profitibility:')
print(format(round(
(f1 if round(y1.value,0) >= 1.0 else 0) + 
(f2 if round(y2.value,0) >= 1.0 else 0) + 
(f3 if round(y3.value,0) >= 1.0 else 0) + 
(f4 if round(y4.value,0) >= 1.0 else 0) + 
(f5 if round(y5.value,0) >= 1.0 else 0) + 
(f6 if round(y6.value,0) >= 1.0 else 0) + 
(f7 if round(y7.value,0) >= 1.0 else 0) + 
(f8 if round(y8.value,0) >= 1.0 else 0) + 
(f9 if round(y9.value,0) >= 1.0 else 0) + 
(f10 if round(y10.value,0) >= 1.0 else 0) + 
(f11 if round(y11.value,0) >= 1.0 else 0) + 
(f12 if round(y12.value,0) >= 1.0 else 0) + 
(f13 if round(y13.value,0) >= 1.0 else 0) + 
(f14 if round(y14.value,0) >= 1.0 else 0) + 
(f15 if round(y15.value,0) >= 1.0 else 0) + 
(f16 if round(y16.value,0) >= 1.0 else 0)
,2)))
# Out:
# Hotel 1 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $2925000
# Hotel 2 ------- If 0, do not purchase if 1, purchase ------ -0.0 ----- Price: $10000000
# Hotel 3 ------- If 0, do not purchase if 1, purchase ------ -0.0 ----- Price: $3750000
# Hotel 4 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $3500000
# Hotel 5 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $325000
# Hotel 6 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $8950000
# Hotel 7 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1950000
# Hotel 8 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1750000
# Hotel 9 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $4900000
# Hotel 10 ------ If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1650000
# Hotel 11 ------ If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1125000
# ...

# %% [markdown]
# ## Part 5<a id='ex3a'></a>
#
# LQM thinks that buying too many hotels in one city is probably not a good idea and would prefer to diversify across as many cities as possible. Add constraint(s) to your model to limit the number of hotels purchased in any city to at most 2.
# ##### What are the constraints that you need to add to the model? Intuitively, do you expect the new optimal objective function value to be larger, smaller or the same as before?
# We need to add a constraint in regard to the city that the hotel is in. In this case, this would come in the form of a new constraint variable per city, that makes sure there are no more than 2 per city.
#
# ##### Write the new optimization model.
#
#
# ##### Solve the new model. Give the values of the decision variables and the optimal objective function value. How does this compare to the previous solution?
# This new solution will provide at best the same optimal solution, but possibly a worse one. In optimization problems adding constraints limits your flexibility when choosing a solution that might be more profitible.
#
# When you have a budget of 10 million, the optimal profitibility drops to 205.7 whereas it was 269.92 before adding the constraint of limited hotels per city. While this constraint makes logical sense from a business perspective, it diminishes our optimal.

# %%
# Increasing the budget to 20 million

import math
import numpy as np
import cvxpy as cvx

# Definition of the Variables
y1 = cvx.Bool()
y2 = cvx.Bool()
y3 = cvx.Bool()
y4 = cvx.Bool()
y5 = cvx.Bool()
y6 = cvx.Bool()
y7 = cvx.Bool()
y8 = cvx.Bool()
y9 = cvx.Bool()
y10 = cvx.Bool()
y11 = cvx.Bool()
y12 = cvx.Bool()
y13 = cvx.Bool()
y14 = cvx.Bool()
y15 = cvx.Bool()
y16 = cvx.Bool()

# price
p1 = 2925000
p2 = 10000000
p3 = 3750000
p4 = 3500000
p5 = 325000
p6 = 8950000
p7 = 1950000
p8 = 1750000
p9 = 4900000
p10 = 1650000
p11 = 1125000
p12 = 2500000
p13 = 1975000
p14 = 3750000
p15 = 1475000
p16 = 750000

# profitibility
f1 = 44.24
f2 = 53.38
f3 = 43.02
f4 = 42.61
f5 = 37.34
f6 = 49.1
f7 = 23.78
f8 = 23.45
f9 = 28.67
f10 = 38.88
f11 = 38.01
f12 = 40.29
f13 = 39.42
f14 = 42.36
f15 = 38.59
f16 = 37.39

#Objective Function
objective_profit = ((f1*y1)+(f2*y2)+(f3*y3)+(f4*y4)+(f5*y5)+(f6*y6)+(f7*y7)+(f8*y8)+(f9*y9)+(f10*y10)+
                   (f11*y11)+(f12*y12)+(f13*y13)+(f14*y14)+(f15*y15)+(f16*y16))
objective = cvx.Maximize(objective_profit)

#Constraints
# total budget constraint
c1=((p1*y1)+(p2*y2)+(p3*y3)+(p4*y4)+(p5*y5)+(p6*y6)+(p7*y7)+(p8*y8)+(p9*y9)+(p10*y10)+(p11*y11)+
    (p12*y12)+(p13*y13)+(p14*y14)+(p15*y15)+(p16*y16)) <= 10000000

# more than 2 per city constraint
c2=(y2+y3+y4+y5) <= 2 # Fresno
c3=(y7+y8+y9)<=2 # Los Angeles
c4=(y10+y11+y12+y13+y14+y15+y16) <= 2 # South Lake Tahoe

con = [c1,c2,c3,c4]


#Solution
prob = cvx.Problem(objective, con)
prob.solve()

# Print the Results
print('Hotel 1 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y1.value,0))+
     ' ------ Price: $'+format(p1))
print('Hotel 2 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y2.value,0))+
     ' ----- Price: $'+format(p2))
print('Hotel 3 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y3.value,0))+
     ' ----- Price: $'+format(p3))
print('Hotel 4 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y4.value,0))+
     ' ------ Price: $'+format(p4))
print('Hotel 5 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y5.value,0))+
     ' ------ Price: $'+format(p5))
print('Hotel 6 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y6.value,0))+
     ' ------ Price: $'+format(p6))
print('Hotel 7 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y7.value,0))+
     ' ------ Price: $'+format(p7))
print('Hotel 8 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y8.value,0))+
     ' ------ Price: $'+format(p8))
print('Hotel 9 ------- If 0, do not purchase if 1, purchase ------ '+format(round(y9.value,0))+
     ' ----- Price: $'+format(p9))
print('Hotel 10 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y10.value,0))+
     ' ------ Price: $'+format(p10))
print('Hotel 11 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y11.value,0))+
     ' ----- Price: $'+format(p11))
print('Hotel 12 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y12.value,0))+
     ' ----- Price: $'+format(p12))
print('Hotel 13 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y13.value,0))+
     ' ----- Price: $'+format(p13))
print('Hotel 14 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y14.value,0))+
     ' ----- Price: $'+format(p14))
print('Hotel 15 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y15.value,0))+
     ' ----- Price: $'+format(p15))
print('Hotel 16 ------ If 0, do not purchase if 1, purchase ------ '+format(round(y16.value,0))+
     ' ------ Price: $'+format(p16))
print('Total Profitibility:')
print(format(round(
(f1 if round(y1.value,0) >= 1.0 else 0) + 
(f2 if round(y2.value,0) >= 1.0 else 0) + 
(f3 if round(y3.value,0) >= 1.0 else 0) + 
(f4 if round(y4.value,0) >= 1.0 else 0) + 
(f5 if round(y5.value,0) >= 1.0 else 0) + 
(f6 if round(y6.value,0) >= 1.0 else 0) + 
(f7 if round(y7.value,0) >= 1.0 else 0) + 
(f8 if round(y8.value,0) >= 1.0 else 0) + 
(f9 if round(y9.value,0) >= 1.0 else 0) + 
(f10 if round(y10.value,0) >= 1.0 else 0) + 
(f11 if round(y11.value,0) >= 1.0 else 0) + 
(f12 if round(y12.value,0) >= 1.0 else 0) + 
(f13 if round(y13.value,0) >= 1.0 else 0) + 
(f14 if round(y14.value,0) >= 1.0 else 0) + 
(f15 if round(y15.value,0) >= 1.0 else 0) + 
(f16 if round(y16.value,0) >= 1.0 else 0)
,2)))
# Out:
# Hotel 1 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $2925000
# Hotel 2 ------- If 0, do not purchase if 1, purchase ------ 0.0 ----- Price: $10000000
# Hotel 3 ------- If 0, do not purchase if 1, purchase ------ 0.0 ----- Price: $3750000
# Hotel 4 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $3500000
# Hotel 5 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $325000
# Hotel 6 ------- If 0, do not purchase if 1, purchase ------ 0.0 ------ Price: $8950000
# Hotel 7 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1950000
# Hotel 8 ------- If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1750000
# Hotel 9 ------- If 0, do not purchase if 1, purchase ------ -0.0 ----- Price: $4900000
# Hotel 10 ------ If 0, do not purchase if 1, purchase ------ 1.0 ------ Price: $1650000
# Hotel 11 ------ If 0, do not purchase if 1, purchase ------ 1.0 ----- Price: $1125000
# ...

# %% [markdown]
# ## Part 6<a id='ex3a'></a>
#
# In one paragraph (no more than 300 words), describe how you would present your results to
# LQM. Do you have any recommendations for them to improve the regression model? How about to improve the optimization model?
#
# The results from this analysis should be used by LQM to influence their hotel purchasing behavior and improve their model. If they are confident in their regression model, then I would recommend to them to consult their other business units in order to find the budget that they are comfortable spending on new hotels. This optimization problem will allow them to maximize profitibility while staying within a pre-defined budget range. However, their budget is not something that this optimization can determine for them, so that is why they need to consult other parts of their business first.
#
# In terms of their regression equation, however, I do think there is room for improvement. When looking at the results, some of the values were not intuitive such as state population having a negative impact on the profitibility of the hotel. In this case, it is likely an issue with all the hotels being located in the same state, but the result does not make intuitive sense. I would recommend that the model be re-evaluated again before this optimization model is implemented, because the regression is the foundation of the optimization; it will spit out an answer, but that answer is only as accurate as the regression.
